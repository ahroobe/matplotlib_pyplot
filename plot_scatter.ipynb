# %% [markdown]
# # Plot scatter graph
#
# * data set : pandas form (csv->pandas)
# * font : Times new Roman
#
# ---
#
# In here, We will learn
# * How to draw scatter plot.
# * How to change font style.
# * How to change font size.
# * How to change marker style.
# * How to draw legend.
# * How to draw grid.
# * How to save chart to eps format.
#
# ## 1. Load dataset

# %%
import pandas as pd
data = pd.read_csv('./python/cbt5_log/0_100_day.csv')
data.head()
# Out:
#    highest_crime   die_num  pvpdie_num  family_num  friend_num   harve_num  \
# 0              5  8.444444           0           1           3   21.111111
# 1             32  6.230769           0           0           8   45.692308
# 2             11  2.555556           0           0          25  130.166667
# 3             22  4.583333           0           0           5  105.916667
# 4             12  3.533333           1           0           1   95.133333
#
#    highlevel   ind_num  jail_num  kick_num  pvpkill_num  comquest_num  \
# 0         20  0.111111         0         0            0     29.111111
# 1         23  0.076923         0         0            0     27.538462
# 2         49  0.666667         0         0            1     64.888889
# 3         30  0.000000         0         1            0     40.833333
# 4         36  0.000000         0         0            1     51.533333
#
#    failquest_num  ship_num  avg_peop   soc_num  label  guild
# 0            1.0         0  2.923077  1.444444  socOK      0
# 1            0.0         0  2.571429  0.538462  allOK      0
# 2            1.0         1  4.129032  1.722222  allOK      0
# 3            0.0         0  3.000000  0.166667  allOK      0
# 4            0.0         0  0.000000  0.000000  indOK      0

# %% [markdown]
# Dataset has 23 columns and every columns except churn and label are numeric.
#
#
# ## 2. Plot the chart
#
# 1) Split dataframe by specific column.
#
# 2) Plot it by using scatter.

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
# First, split data by 'label' column.
data_all = data.loc[data['label']=='allOK']
data_soc = data.loc[data['label']=='socOK']
data_ind = data.loc[data['label']=='indOK']
data_no = data.loc[data['label']=='noOK']

# %% [markdown]
# We can select data by indexing, Example is ```ax.scatter(data_all[X_column],data_all[Y_column],color='r',alpha=.4,label='first_label')```
#
# First 2 elements are for X axis and Y axis, **color** is for coloring (i.e. r,g,b,gray,yellow and etc), **alpha** is for transparency and **label** is for legend.

# %%
fig, ax = plt.subplots()
ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')
## Make a legend at upper right
plt.legend(loc='upper right')
## X, Y label name
plt.xlabel('die #')
plt.ylabel('level')
plt.show()

# %% [markdown]
# ## 3. Customizing
#
# * Legend
# * Font
# * Line
#
# ### 1) Legend Location Types
#
# | **Location String** | **Location Code** |
# |:---------------:|---------------|
# |       best      |       0       |
# |   upper right   |       1       |
# |    upper left   |       2       |
# |    lower left   |       3       |
# |   lower right   |       4       |
# |      right      |       5       |
# |   center left   |       6       |
# |   center right  |       7       |
# |   lower center  |       8       |
# |   upper center  |       9       |
# |      center     |       10      |
#
# ### 2) Change Font
#
# ```
# mpl.rc('font',family='serif',serif='Times New Roman', size=15)
# ```
# For same code, Let's change the font of X, Y labels and title.
#
# I will use Times New Roman font. Below code makes Every matplotlib font-type to 'Times New Roman' and size to 15.
#
# **IF Times New Roman becomes bold, just run below code will solve this problem**

# %%
## No bold!!
del matplotlib.font_manager.weight_dict['roman']
matplotlib.font_manager._rebuild()

# %%
import matplotlib as mpl
mpl.rc('font',family='serif',serif='Times New Roman', size=15)

# %%
fig, ax = plt.subplots()
ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')
## Make a legend at lower right (no data at lower right corner)
plt.legend(loc='lower right')
## X, Y label name
plt.title('Example of Graph')
plt.xlabel('die #')
plt.ylabel('level')
plt.show()

# %% [markdown]
# ### 3) Markers
#
# ```
# ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,marker="o",label='acculturation')
# ```
#
# There are lots of styles for markers.
# The details in https://matplotlib.org/api/markers_api.html#module-matplotlib.markers.
#
# Let's change all markers to circle, square, triangle_up, triangle_down

# %%
fig, ax = plt.subplots()
ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,marker="o",label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,marker="s",label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,marker="^",label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,marker="v",label='marginality')

## X, Y label name
plt.title('Example of Graph')
plt.xlabel('die #')
plt.ylabel('level')
plt.show()

# %% [markdown]
# ### 4) Font size
#
# ```
# plt.legend(loc='lower right',fontsize=12)
#
# plt.xlabel('die #',fontsize=18)
# plt.ylabel('level',fontsize=18)
#
# ```
# Coordinate every font size.

# %%
fig, ax = plt.subplots()

ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')


plt.legend(loc='lower right',fontsize=12)
plt.xlabel('die #',fontsize=18)
plt.ylabel('level',fontsize=18)
plt.show()

# %% [markdown]
# ### 5) Grid in chart
#
# ```
# plt.grid(alpha=.4,linewidth=.5,linestyle='--')
# ```
# not for scatter plot, grid is mostly needed.
#
# linestyle
# * solid (-)
# * dashed (--)
# * dashdot (-.)
# * dotted (:)
# * None

# %%
fig, ax = plt.subplots()

ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')
plt.legend(loc='lower right',fontsize=12)
plt.xlabel('die #',fontsize=18)
plt.ylabel('level',fontsize=18)

#dashed gray grid
plt.grid(alpha=.4,linewidth=.5,linestyle='--')

plt.show()

# %% [markdown]
# ### 6) Change bold elements to light
#
# Legend and xtics are all bold, so we should change it to light
#
#
# * legend
#
# ```
# weight_property = {'weight':'light'}
# plt.legend(loc='lower right',fontsize=12,prop=weight_property)
# ```
#
# * ticks
#
# ```
# for tick in ax.xaxis.get_major_ticks():
#     tick.label1.set_fontsize(15)
#     tick.label1.set_fontweight('light')
#
# for tick in ax.yaxis.get_major_ticks():
#     tick.label1.set_fontsize(15)
#     tick.label1.set_fontweight('light')
#
# ```

# %%
fig, ax = plt.subplots()

plt.rcParams['axes.labelweight'] = 'light'

ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')

weight_property = {'weight':'light'}
plt.legend(loc='lower right',fontsize=12,prop=weight_property)
## X, Y label name
plt.xlabel('die #',fontsize=18)
plt.ylabel('level',fontsize=18)

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('light')
    
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('light')

#dashed gray grid
plt.grid(alpha=.4,linewidth=.5,linestyle='--')

plt.show()

# %% [markdown]
# ## 4. Save Chart as EPS format.
#
# ```
# plt.savefig('chart.eps', format='eps', dpi=1000)
# ```

# %%
fig, ax = plt.subplots()

plt.rcParams['axes.labelweight'] = 'light'

ax.scatter(data_all['die_num'],data_all['highlevel'],color='r',alpha=.4,label='acculturation')
ax.scatter(data_soc['die_num'],data_soc['highlevel'],color='g',alpha=.4,label='assimilation')
ax.scatter(data_ind['die_num'],data_ind['highlevel'],color='b',alpha=.4,label='separation')
ax.scatter(data_no['die_num'],data_no['highlevel'],color='black',alpha=.4,label='marginality')

weight_property = {'weight':'light'}
plt.legend(loc='lower right',fontsize=12,prop=weight_property)
## X, Y label name
plt.xlabel('die #',fontsize=18)
plt.ylabel('level',fontsize=18)

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('light')
    
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('light')

#dashed gray grid
plt.grid(alpha=.4,linewidth=.5,linestyle='--')

plt.savefig('./chart/scatter_plot.eps', format='eps', dpi=1000)
